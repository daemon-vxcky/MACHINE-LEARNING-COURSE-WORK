# %% [markdown]
# # 19CSE305 ML - Pandas Exercise Questions - 23rd Aug 2023

# %% [markdown]
# ### Task 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Task 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Task 3. Use the tsv file and assign it to a dataframe called food

# %% [markdown]
# ### Task 4. See the first 5 entries

# %% [markdown]
# ### Task 5. What is the number of observations in the dataset?

# %% [markdown]
# ### Task 6. What is the number of columns in the dataset?

# %% [markdown]
# ### Task 7. Print the name of all the columns.

# %% [markdown]
# ### Task 8. What is the name of 105th column?

# %% [markdown]
# ### Task 9. What is the type of the observations of the 105th column?

# %% [markdown]
# ### Task 10. How is the dataset indexed?

# %% [markdown]
# ### Task 11. What is the product name of the 19th observation?

# %% [markdown]
# ### Task 12. How many columns in the dataset tend to have null values?

# %% [markdown]
# ### Task 13. Find the number of null values present under each column?

# %% [markdown]
# ### Task 14. Create a dictionary with keys to be column names in the dataset and values to number of null values under each column. Print the dictionary by iterating through its elements using a for loop.

# %% [markdown]
# ### Task 15. Display the values associated with all columns from row 108 to 208?

# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (1.5.16)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: six>=1.10 in c:\users\vigne\appdata\roaming\python\python311\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2023.5.7)
# Requirement already satisfied: python-dateutil in c:\users\vigne\appdata\roaming\python\python311\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (1.26.16)
# Requirement already satisfied: bleach in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from requests->kaggle) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vigne\appdata\local\programs\python\python311\lib\site-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: colorama in c:\users\vigne\appdata\roaming\python\python311\site-packages (from tqdm->kaggle) (0.4.6)

# %%
# !mkdir kaggle
# Out:
# A subdirectory or file kaggle already exists.

# %%
# !cp kaggle.json ~/.kaggle
# Out:
# 'cp' is not recognized as an internal or external command,
# operable program or batch file.

# %%
kaggle datasets download -d openfoodfacts/world-food-facts
# Out:
#   Cell In[18], line 1
#     kaggle datasets download -d openfoodfacts/world-food-facts
#            ^
# SyntaxError: invalid syntax
